# %%
# imports
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

pd.options.plotting.backend = "plotly"

from pmdarima.preprocessing import FourierFeaturizer
from sktime.performance_metrics.forecasting import (
    mean_absolute_scaled_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    mean_squared_error,
)
from pmdarima import auto_arima, ARIMA
import time

# %% [markdown]
# ## read data

# %%
df_store = pd.read_pickle("data/df_daily.pkl")
df_company = df_store.groupby("date").sum()[["sales"]]
df_exog = pd.read_pickle("data/df_exog.pkl")

# %% [markdown]
# ## define functions

# %%
def preprocessing(ts, df_exog, split=True, steps_ahead=30):
    """
    split: to split into train and test set
    """
    print(f"Preprocessing timeseries data with {steps_ahead} steps ahead")
    ts = ts["sales"] / 1e6
    ts.index.freq = "D"
    df_exog=df_exog.loc[ts.index]
    
    if split:
        # split
        y_train = ts.iloc[:-steps_ahead]
        y_test = ts.iloc[-steps_ahead:]
        exog_train = df_exog.iloc[:-steps_ahead]
        exog_test = df_exog.iloc[-steps_ahead:]
        return {
            "y_train": y_train,
            "y_test": y_test,
            "exog_train": exog_train,
            "exog_test": exog_test,
        }
    else:
        return {"y": ts, "exog": df_exog}


def auto_arima_model(y_train, exog_train, diff_num):
    time_start = time.time()
    print("start auto arima...")
    # Fit model to the level to find common order
    arima_model = auto_arima(
        y=y_train,
        exogenous=exog_train,
        D=diff_num,
        seasonal=True,
        m=7,  # Weekly seasonality
    )
    time_stop = time.time()
    print(f"finished auto arima, total time: {time_stop-time_start}")
    return arima_model


def fit_arima_model(arima_model, model_name, arima_data):
    y_train = arima_data["y_train"]
    y_test = arima_data["y_test"]
    exog_train = arima_data["exog_train"]
    exog_test = arima_data["exog_test"]
    # Forecast
    arima_y_fitted = arima_model.predict_in_sample(X=exog_train)

    arima_y_forecast = arima_model.predict(n_periods=len(y_test), exogenous=exog_test)

    arima_y_forecast = pd.Series(arima_y_forecast, name="forecast", index=y_test.index)

    # metrics evaluation
    # in-sample
    mae_IS = round(mean_absolute_error(y_train, arima_y_fitted))
    mape_IS = round(mean_absolute_percentage_error(y_train, arima_y_fitted), 3)

    # out-sample
    mae_OOS = round(mean_absolute_error(y_test, arima_y_forecast), 3)
    mape_OOS = round(mean_absolute_percentage_error(y_test, arima_y_forecast), 3)
    return {
        "model": model_name,
        "mae_IS": mae_IS,
        "mae_OOS": mae_OOS,
        "mape_IS": mape_IS,
        "mape_OOS": mape_OOS,
    }


def cross_validation_result(data, model, model_name, rolls=4, horizon=30):
    """ """
    mae_CVs = []
    mape_CVs = []
    for i in range(rolls):
        print(f'fold {i}---------------')
        model.fit(
            y=data["y"].iloc[: -(rolls - i) * horizon],
            X=data["exog"].iloc[: -(rolls - i) * horizon],
        )
        y_test = data["y"].iloc[
            np.r_[-(rolls - i) * horizon : -(rolls - i - 1) * horizon]
        ]
        y_hat = model.predict(
            n_periods=horizon,
            exogenous=data["exog"].iloc[
                np.r_[-(rolls - i) * horizon : -(rolls - i - 1) * horizon]
            ],
        )
        mae_CV = round(mean_absolute_error(y_test, y_hat), 3)
        mape_CV = round(mean_absolute_percentage_error(y_test, y_hat), 3)
        mae_CVs.append(mae_CV)
        mape_CVs.append(mape_CV)
    return {
        "model": model_name,
        "mae_CV": np.mean(mae_CVs),
        "mape_CV": np.mean(mape_CVs),
    }

# %% [markdown]
# ## tune on company data

# %%
arima_data = preprocessing(
    ts=df_company, df_exog=df_exog, steps_ahead=30
)

print(arima_data.keys())
# Out:
# Preprocessing timeseries data with 30 steps ahead
#
# dict_keys(['y_train', 'y_test', 'exog_train', 'exog_test'])

# %%
arima_data["exog_train"]
# Out:
#             off_day  promo_day
# date
# 2017-08-07        0          0
# 2017-08-08        0          0
# 2017-08-09        0          0
# 2017-08-10        0          0
# 2017-08-11        0          0
# ...             ...        ...
# 2020-12-28        0          0
# 2020-12-29        0          0
# 2020-12-30        0          0
# 2020-12-31        0          0
# 2021-01-01        0          0
#
# [1244 rows x 2 columns]

# %%
arima_model_whole_company = auto_arima_model(
    y_train=arima_data["y_train"], 
    exog_train=arima_data["exog_train"], 
    diff_num=1
)
print(arima_model_whole_company)
# Out:
# start auto arima...
# finished auto arima, total time: 253.79850220680237
#  ARIMA(1,0,3)(0,1,1)[7] intercept

# %%
result = fit_arima_model(
    arima_model=arima_model_whole_company,
    model_name="whole_company",
    arima_data=arima_data,
)

# %%
result
# Out:
# {'model': 'whole_company',
#  'mae_IS': 127,
#  'mae_OOS': 208.445,
#  'mape_IS': 0.277,
#  'mape_OOS': 0.26}

# %% [markdown]
# ## fit on store data

# %%
all_stores_result_CV = []
for store in df_store["store_id"].unique():
    time_start = time.time()
    print(f"\nprocessing stores {store}...")
    model_name = "store_" + str(store)

    # data
    df_data = df_store[df_store["store_id"] == store].set_index("date")[["sales"]]
    arima_data = preprocessing(
        ts=df_data,
        df_exog=df_exog,
        split=False,
        steps_ahead=30,
    )

    # fit model to each store
    cv_score = cross_validation_result(
        data=arima_data, model=arima_model_whole_company, model_name=model_name
    )

    # result
    all_stores_result_CV.append(cv_score)

    # timing
    time_stop = time.time()
    print(f"finished stores {store}, total time: {time_stop-time_start}")
    
all_stores_result_CV = pd.DataFrame(all_stores_result_CV)
# Out:
# processing stores 307222...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307222, total time: 26.484768629074097
# processing stores 307244...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307244, total time: 28.495460033416748
# processing stores 307248...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307248, total time: 28.795305967330933
# processing stores 320264...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 320264, total time: 28.824748039245605
# processing stores 328165...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 328165, total time: 26.15737295150757
# processing stores 349920...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349920, total time: 29.467586755752563
# processing stores 349924...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349924, total time: 26.734550952911377
# processing stores 349952...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349952, total time: 29.395860195159912
# processing stores 349958...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349958, total time: 30.5157208442688
# processing stores 349962...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349962, total time: 27.546481132507324
# processing stores 349972...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349972, total time: 29.66458797454834
# processing stores 349978...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349978, total time: 29.544861793518066
# processing stores 349980...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349980, total time: 24.371152877807617
# processing stores 349998...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349998, total time: 23.970160722732544
# processing stores 350016...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350016, total time: 24.6432888507843
# processing stores 350018...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350018, total time: 24.61795687675476
# processing stores 350026...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350026, total time: 23.790054082870483
# processing stores 350028...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350028, total time: 24.315408945083618
# processing stores 350040...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350040, total time: 24.140313863754272
# processing stores 350046...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350046, total time: 23.339977264404297
# processing stores 350054...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350054, total time: 24.417555809020996
# processing stores 350056...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350056, total time: 25.17603898048401
# processing stores 350060...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350060, total time: 25.644599199295044
# processing stores 354468...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 354468, total time: 24.57662296295166
# processing stores 387240...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 387240, total time: 22.198299169540405
# processing stores 412585...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 412585, total time: 21.47964906692505
# processing stores 441997...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 441997, total time: 20.86874532699585
# processing stores 452387...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 452387, total time: 19.713348150253296
# processing stores 461349...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 461349, total time: 19.647060871124268
# processing stores 464495...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 464495, total time: 20.220421075820923
# processing stores 471477...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 471477, total time: 19.413156032562256
# processing stores 476061...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 476061, total time: 19.565759897232056
# processing stores 480733...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 480733, total time: 18.766173124313354
# processing stores 528854...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 528854, total time: 16.25189709663391
# processing stores 536898...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 536898, total time: 15.990804195404053
# processing stores 536902...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 536902, total time: 15.436836004257202
# processing stores 566790...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 566790, total time: 14.497338056564331
# processing stores 566792...
# Preprocessing timeseries data with 30 steps ahead
#
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 566792, total time: 15.161530256271362

# %% [markdown]
# ## result

# %%
all_stores_result_CV.to_pickle("results/f8/ARIMA_promo.pkl")

# %%
all_stores_result_CV.head()
# Out:
#           model    mae_CV  mape_CV
# 0  store_307222   9.40700  0.32875
# 1  store_307244   7.12975  0.35450
# 2  store_307248   7.06150  0.41025
# 3  store_320264   5.61600  0.43950
# 4  store_328165  29.00050  0.45300

# %%
all_stores_result_CV.describe()
# Out:
#           mae_CV    mape_CV
# count  38.000000  38.000000
# mean    7.847007   0.452066
# std     5.777859   0.085296
# min     3.015250   0.322000
# 25%     4.020062   0.383438
# 50%     6.554000   0.440500
# 75%     9.063438   0.500750
# max    29.000500   0.659250
