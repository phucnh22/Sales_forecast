# %%
# imports
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

pd.options.plotting.backend = "plotly"

from pmdarima.preprocessing import FourierFeaturizer
from sktime.performance_metrics.forecasting import (
    mean_absolute_scaled_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    mean_squared_error,
)
from pmdarima import auto_arima, ARIMA
import time
# Out:
# /Users/giangphan23/OneDrive - Norges Handelshøyskole/Thesis/Sales_forecast/ap8venv/lib/python3.8/site-packages/sktime/utils/validation/series.py:22: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# # read data

# %%
df_store = pd.read_pickle("data/df_daily.pkl")
df_company = df_store.groupby("date").sum()[["sales"]]
df_exog = pd.read_pickle("data/df_exog.pkl")

# %% [markdown]
# # define functions

# %%
def preprocessing(ts, df_exog, horizon, split=True):
    """
    split: to split into train and test set
    """
    print(f"Preprocessing timeseries data with {horizon} steps ahead")
    ts = ts["sales"] / 1e6
    ts.index.freq = "D"
    df_exog = df_exog.loc[ts.index]

    if split:
        # split
        y_train = ts.iloc[:-horizon]
        y_test = ts.iloc[-horizon:]
        exog_train = df_exog.iloc[:-horizon]
        exog_test = df_exog.iloc[-horizon:]
        return {
            "y_train": y_train,
            "y_test": y_test,
            "exog_train": exog_train,
            "exog_test": exog_test,
        }
    else:
        return {"y": ts, "exog": df_exog}


def auto_arima_model(y_train, exog_train, diff_num):
    time_start = time.time()
    print("start auto arima...")
    # Fit model to the level to find common order
    arima_model = auto_arima(
        y=y_train,
        exogenous=exog_train,
        D=diff_num,
        seasonal=True,
        m=7,  # Weekly seasonality
    )
    time_stop = time.time()
    print(f"finished auto arima, total time: {time_stop-time_start}")
    return arima_model


def fit_arima_model(arima_model, model_name, arima_data):
    y_train = arima_data["y_train"]
    y_test = arima_data["y_test"]
    exog_train = arima_data["exog_train"]
    exog_test = arima_data["exog_test"]
    # Forecast
    arima_y_fitted = arima_model.predict_in_sample(X=exog_train)
    arima_y_forecast = arima_model.predict(n_periods=len(y_test), exogenous=exog_test)
    arima_y_forecast = pd.Series(arima_y_forecast, name="forecast", index=y_test.index)

    # metrics evaluation
    # in-sample
    mae_IS = round(mean_absolute_error(y_train, arima_y_fitted))
    mape_IS = round(mean_absolute_percentage_error(y_train, arima_y_fitted), 3)

    # out-sample
    mae_OOS = round(mean_absolute_error(y_test, arima_y_forecast), 3)
    mape_OOS = round(mean_absolute_percentage_error(y_test, arima_y_forecast), 3)
    return {
        "model": model_name,
        "mae_IS": mae_IS,
        "mae_OOS": mae_OOS,
        "mape_IS": mape_IS,
        "mape_OOS": mape_OOS,
    }


def cross_validation_result(data, model, model_name, horizon, rolls=4):
    """ """
    mae_CVs = []
    rmse_CVs = []
    mape_CVs = []
    mase_CVs = []
    for i in range(rolls):
        # print(f"fold {i}---------------")
        y_train = data["y"].iloc[: -(rolls - i) * horizon]
        y_test = data["y"].iloc[
            np.r_[-(rolls - i) * horizon : -(rolls - i - 1) * horizon]]
        
        model.fit(
            y=y_train,
            X=data["exog"].iloc[: -(rolls - i) * horizon])
        
        y_hat = model.predict(
            n_periods=horizon,
            exogenous=data["exog"].iloc[
                np.r_[-(rolls - i) * horizon : -(rolls - i - 1) * horizon]])

        mae_CVs.append(round(mean_absolute_error(y_test, y_hat), 3))
        rmse_CVs.append(round(mean_squared_error(y_test, y_hat, square_root=True), 3))
        mape_CVs.append(round(mean_absolute_percentage_error(y_test, y_hat), 3))
        mase_CVs.append(round(mean_absolute_scaled_error(y_test, y_hat, y_train=y_train), 3))
    
    return {'store':model_name,
           'mae_ARIMA':np.mean(mae_CVs),
           'rmse_ARIMA':np.mean(rmse_CVs),
           'mape_ARIMA':np.mean(mape_CVs),
           'mase_ARIMA':np.mean(mase_CVs),
           'fc_ARIMA':y_hat,
           }

# %% [markdown]
# # horizon = 7

# %% [markdown]
# ## tune on company data

# %%
horizon = 7
arima_data = preprocessing(ts=df_company, df_exog=df_exog, horizon=horizon)
print(arima_data.keys())
# Out:
# Preprocessing timeseries data with 7 steps ahead
# dict_keys(['y_train', 'y_test', 'exog_train', 'exog_test'])

# %%
arima_data['y_train']
# Out:
# date
# 2017-08-07       1.527650
# 2017-08-08       0.000000
# 2017-08-09      34.942320
# 2017-08-10      20.151840
# 2017-08-11      24.305380
#                  ...
# 2021-01-20     653.033192
# 2021-01-21     595.027497
# 2021-01-22     745.327841
# 2021-01-23    1207.594290
# 2021-01-24    1672.900088
# Freq: D, Name: sales, Length: 1267, dtype: float64

# %%
arima_model_whole_company = auto_arima_model(
    y_train=arima_data["y_train"], 
    exog_train=arima_data["exog_train"], 
    diff_num=1,
)
print(arima_model_whole_company) # ARIMA(1,0,3)(0,1,1)[7] intercept
# Out:
# start auto arima...
# finished auto arima, total time: 103.73086977005005
#  ARIMA(1,0,1)(0,1,1)[7] intercept

# %%
# from joblib import dump, load
# # Save model
# dump(arima_model_whole_company, filename='results/f8/ARIMA_forecaster_7.py')

# # Load model
# arima_model_whole_company = load('results/f8/ARIMA_forecaster_7.py')

# %% [markdown]
# ## fit on store data

# %%
# arima_model_whole_company = ARIMA((1,0,3), (0,1,1,7))

# %%
all_stores_result_CV = []
for store in df_store["store_id"].unique():#[:2]:
    time_start = time.time()
    print(f"\nprocessing stores {store}...")
    model_name = "store_" + str(store)

    # data
    df_data = df_store[df_store["store_id"] == store].set_index("date")[["sales"]]
    arima_data = preprocessing(
        ts=df_data,
        df_exog=df_exog,
        horizon=horizon,
        split=False,
        )

    # fit model to each store
    cv_score = cross_validation_result(
        data=arima_data, 
        model=arima_model_whole_company, 
        model_name=model_name,
        horizon=horizon,
        )

    # result
    all_stores_result_CV.append(cv_score)

    # timing
    time_stop = time.time()
    print(f"finished stores {store}, total time: {time_stop-time_start}")
    
all_stores_result_CV = pd.DataFrame(all_stores_result_CV)
# Out:
# processing stores 307222...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307222, total time: 34.460044145584106
#
# processing stores 307244...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307244, total time: 31.19917106628418
#
# processing stores 307248...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307248, total time: 26.74669098854065
#
# processing stores 320264...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 320264, total time: 28.19735312461853
#
# processing stores 328165...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 328165, total time: 23.720897912979126
#
# processing stores 349920...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349920, total time: 30.683583974838257
#
# processing stores 349924...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349924, total time: 28.36095380783081
#
# processing stores 349952...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349952, total time: 24.129802942276
#
# processing stores 349958...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349958, total time: 32.2337601184845
#
# processing stores 349962...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349962, total time: 30.624932050704956
#
# processing stores 349972...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349972, total time: 38.59438395500183
#
# processing stores 349978...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349978, total time: 29.158029079437256
#
# processing stores 349980...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349980, total time: 17.05786418914795
#
# processing stores 349998...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349998, total time: 26.56318712234497
#
# processing stores 350016...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350016, total time: 27.509346961975098
#
# processing stores 350018...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350018, total time: 28.70055913925171
#
# processing stores 350026...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350026, total time: 27.905391931533813
#
# processing stores 350028...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350028, total time: 29.465999841690063
#
# processing stores 350040...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350040, total time: 29.326496124267578
#
# processing stores 350046...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350046, total time: 23.61887526512146
#
# processing stores 350054...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350054, total time: 31.64012598991394
#
# processing stores 350056...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350056, total time: 22.608531951904297
#
# processing stores 350060...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350060, total time: 29.99490785598755
#
# processing stores 354468...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 354468, total time: 19.986222982406616
#
# processing stores 387240...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 387240, total time: 13.58010196685791
#
# processing stores 412585...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 412585, total time: 18.53627300262451
#
# processing stores 441997...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 441997, total time: 21.322371244430542
#
# processing stores 452387...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 452387, total time: 27.07338809967041
#
# processing stores 461349...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 461349, total time: 25.714592218399048
#
# processing stores 464495...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 464495, total time: 16.381930828094482
#
# processing stores 471477...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 471477, total time: 24.63418984413147
#
# processing stores 476061...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 476061, total time: 21.511110067367554
#
# processing stores 480733...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 480733, total time: 13.345331907272339
#
# processing stores 528854...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 528854, total time: 22.633068084716797
#
# processing stores 536898...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 536898, total time: 18.184252977371216
#
# processing stores 536902...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 536902, total time: 14.258461952209473
#
# processing stores 566790...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 566790, total time: 20.37199831008911
#
# processing stores 566792...
# Preprocessing timeseries data with 7 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 566792, total time: 17.390923976898193

# %% [markdown]
# ## result

# %%
# all_stores_result_CV.to_pickle("results/f8/ARIMA_result_7.pkl")

# %% [markdown]
# # horizon = 14

# %% [markdown]
# ## tune on company data

# %%
horizon = 14
arima_data = preprocessing(ts=df_company, df_exog=df_exog, horizon=horizon)
print(arima_data.keys())
# Out:
# Preprocessing timeseries data with 14 steps ahead
# dict_keys(['y_train', 'y_test', 'exog_train', 'exog_test'])

# %%
arima_model_whole_company = auto_arima_model(
    y_train=arima_data["y_train"], 
    exog_train=arima_data["exog_train"], 
    diff_num=1,
    
)
print(arima_model_whole_company) # ARIMA(1,0,3)(0,1,1)[7] intercept
# Out:
# start auto arima...
# finished auto arima, total time: 204.3140480518341
#  ARIMA(0,0,3)(0,1,1)[7]

# %%
# from joblib import dump, load
# # Save model
# dump(arima_model_whole_company, filename='results/f8/ARIMA_forecaster_14.py')

# # Load model
# arima_model_whole_company = load('results/f8/ARIMA_forecaster_14.py')

# %% [markdown]
# ## fit on store data

# %%
# arima_model_whole_company = ARIMA((1,0,3), (0,1,1,7))

# %%
all_stores_result_CV = []
for store in df_store["store_id"].unique():#[:2]:
    time_start = time.time()
    # print(f"\nprocessing stores {store}...")
    model_name = "store_" + str(store)

    # data
    df_data = df_store[df_store["store_id"] == store].set_index("date")[["sales"]]
    arima_data = preprocessing(
        ts=df_data,
        df_exog=df_exog,
        horizon=horizon,
        split=False,
        )

    # fit model to each store
    cv_score = cross_validation_result(
        data=arima_data, 
        model=arima_model_whole_company, 
        model_name=model_name,
        horizon=horizon,
        )

    # result
    all_stores_result_CV.append(cv_score)

    # timing
    time_stop = time.time()
    print(f"finished stores {store}, total time: {time_stop-time_start}")
    
all_stores_result_CV = pd.DataFrame(all_stores_result_CV)
# Out:
# processing stores 307222...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307222, total time: 13.54040002822876
#
# processing stores 307244...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307244, total time: 13.858042240142822
#
# processing stores 307248...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307248, total time: 13.794012069702148
#
# processing stores 320264...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 320264, total time: 16.285012006759644
#
# processing stores 328165...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 328165, total time: 19.763464212417603
#
# processing stores 349920...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349920, total time: 14.870528936386108
#
# processing stores 349924...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349924, total time: 19.865189790725708
#
# processing stores 349952...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349952, total time: 14.507691144943237
#
# processing stores 349958...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349958, total time: 15.047595024108887
#
# processing stores 349962...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349962, total time: 17.042267322540283
#
# processing stores 349972...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349972, total time: 21.548317909240723
#
# processing stores 349978...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349978, total time: 27.381497859954834
#
# processing stores 349980...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349980, total time: 22.764764308929443
#
# processing stores 349998...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349998, total time: 24.87004804611206
#
# processing stores 350016...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350016, total time: 25.49389624595642
#
# processing stores 350018...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350018, total time: 26.122531175613403
#
# processing stores 350026...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350026, total time: 19.980284929275513
#
# processing stores 350028...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350028, total time: 17.062355756759644
#
# processing stores 350040...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350040, total time: 24.13463592529297
#
# processing stores 350046...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350046, total time: 24.31446099281311
#
# processing stores 350054...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350054, total time: 25.445066928863525
#
# processing stores 350056...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350056, total time: 18.183500051498413
#
# processing stores 350060...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350060, total time: 27.04949712753296
#
# processing stores 354468...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 354468, total time: 24.35135316848755
#
# processing stores 387240...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 387240, total time: 20.974586725234985
#
# processing stores 412585...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 412585, total time: 23.697800874710083
#
# processing stores 441997...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 441997, total time: 16.866291046142578
#
# processing stores 452387...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 452387, total time: 18.486358165740967
#
# processing stores 461349...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 461349, total time: 18.879723072052002
#
# processing stores 464495...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 464495, total time: 13.871583938598633
#
# processing stores 471477...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 471477, total time: 17.28430199623108
#
# processing stores 476061...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 476061, total time: 18.26793098449707
#
# processing stores 480733...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 480733, total time: 14.025285720825195
#
# processing stores 528854...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 528854, total time: 17.986225128173828
#
# processing stores 536898...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 536898, total time: 16.188555002212524
#
# processing stores 536902...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 536902, total time: 15.638187170028687
#
# processing stores 566790...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 566790, total time: 8.671989917755127
#
# processing stores 566792...
# Preprocessing timeseries data with 14 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 566792, total time: 12.540928840637207

# %% [markdown]
# ## result

# %%
# Save result
# all_stores_result_CV.to_pickle("results/f8/ARIMA_result_14.pkl")

# %% [markdown]
# # horizon = 21

# %% [markdown]
# ## tune on company data

# %%
horizon = 21
arima_data = preprocessing(ts=df_company, df_exog=df_exog, horizon=horizon)
print(arima_data.keys())
# Out:
# Preprocessing timeseries data with 21 steps ahead
# dict_keys(['y_train', 'y_test', 'exog_train', 'exog_test'])

# %%
arima_model_whole_company = auto_arima_model(
    y_train=arima_data["y_train"], 
    exog_train=arima_data["exog_train"], 
    diff_num=1,
    
)
print(arima_model_whole_company) # ARIMA(1,0,3)(0,1,1)[7] intercept
# Out:
# start auto arima...
# finished auto arima, total time: 161.90804886817932
#  ARIMA(0,0,3)(0,1,1)[7] intercept

# %%
from joblib import dump, load
# Save model
dump(arima_model_whole_company, filename='results/f8/ARIMA_forecaster_21.py')

# Load model
arima_model_whole_company = load('results/f8/ARIMA_forecaster_21.py')

# %% [markdown]
# ## fit on store data

# %%
# arima_model_whole_company = ARIMA((1,0,3), (0,1,1,7))

# %%
all_stores_result_CV = []
for store in df_store["store_id"].unique():#[:2]:
    time_start = time.time()
    # print(f"\nprocessing stores {store}...")
    model_name = "store_" + str(store)

    # data
    df_data = df_store[df_store["store_id"] == store].set_index("date")[["sales"]]
    arima_data = preprocessing(
        ts=df_data,
        df_exog=df_exog,
        horizon=horizon,
        split=False,
        )

    # fit model to each store
    cv_score = cross_validation_result(
        data=arima_data, 
        model=arima_model_whole_company, 
        model_name=model_name,
        horizon=horizon,
        )

    # result
    all_stores_result_CV.append(cv_score)

    # timing
    time_stop = time.time()
    # print(f"finished stores {store}, total time: {time_stop-time_start}")
    
all_stores_result_CV = pd.DataFrame(all_stores_result_CV)
# Out:
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead
# Preprocessing timeseries data with 21 steps ahead

# %% [markdown]
# ## result

# %%
# Save result
all_stores_result_CV.to_pickle("results/f8/ARIMA_result_21.pkl")

# %% [markdown]
# # horizon = 28

# %% [markdown]
# ## tune on company data

# %%
horizon = 28
arima_data = preprocessing(ts=df_company, df_exog=df_exog, horizon=horizon)
print(arima_data.keys())
# Out:
# Preprocessing timeseries data with 28 steps ahead
# dict_keys(['y_train', 'y_test', 'exog_train', 'exog_test'])

# %%
arima_model_whole_company = auto_arima_model(
    y_train=arima_data["y_train"], 
    exog_train=arima_data["exog_train"], 
    diff_num=1,
    
)
print(arima_model_whole_company) # ARIMA(1,0,3)(0,1,1)[7] intercept
# Out:
# start auto arima...
# finished auto arima, total time: 322.09505581855774
#  ARIMA(0,0,3)(0,1,1)[7] intercept

# %%
from joblib import dump, load
# Save model
dump(arima_model_whole_company, filename='results/f8/ARIMA_forecaster_28.py')

# Load model
# arima_model_whole_company = load('results/f8/ARIMA_forecaster_21.py')
# Out:
# ['results/f8/ARIMA_forecaster_28.py']

# %% [markdown]
# ## fit on store data

# %%
# arima_model_whole_company = ARIMA((1,0,3), (0,1,1,7))

# %%
all_stores_result_CV = []
for store in df_store["store_id"].unique():#[:2]:
    time_start = time.time()
    # print(f"\nprocessing stores {store}...")
    model_name = "store_" + str(store)

    # data
    df_data = df_store[df_store["store_id"] == store].set_index("date")[["sales"]]
    arima_data = preprocessing(
        ts=df_data,
        df_exog=df_exog,
        horizon=horizon,
        split=False,
        )

    # fit model to each store
    cv_score = cross_validation_result(
        data=arima_data, 
        model=arima_model_whole_company, 
        model_name=model_name,
        horizon=horizon,
        )

    # result
    all_stores_result_CV.append(cv_score)

    # timing
    time_stop = time.time()
    # print(f"finished stores {store}, total time: {time_stop-time_start}")
    
all_stores_result_CV = pd.DataFrame(all_stores_result_CV)
# Out:
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead
# Preprocessing timeseries data with 28 steps ahead

# %% [markdown]
# ## result

# %%
# Save result
all_stores_result_CV.to_pickle("results/f8/ARIMA_result_28.pkl")
