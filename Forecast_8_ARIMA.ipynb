# %%
# imports
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

pd.options.plotting.backend = "plotly"

from pmdarima.preprocessing import FourierFeaturizer
from sktime.performance_metrics.forecasting import (
    mean_absolute_scaled_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    mean_squared_error,
)
from pmdarima import auto_arima, ARIMA
import time

# %% [markdown]
# # read data

# %%
df_store = pd.read_pickle("data/df_daily.pkl")
df_company = df_store.groupby("date").sum()[["sales"]]
df_exog = pd.read_pickle("data/df_exog.pkl")

# %% [markdown]
# # define functions

# %%
def preprocessing(ts, df_exog, split=True, steps_ahead=30):
    """
    split: to split into train and test set
    """
    print(f"Preprocessing timeseries data with {steps_ahead} steps ahead")
    ts = ts["sales"] / 1e6
    ts.index.freq = "D"
    df_exog = df_exog.loc[ts.index]

    if split:
        # split
        y_train = ts.iloc[:-steps_ahead]
        y_test = ts.iloc[-steps_ahead:]
        exog_train = df_exog.iloc[:-steps_ahead]
        exog_test = df_exog.iloc[-steps_ahead:]
        return {
            "y_train": y_train,
            "y_test": y_test,
            "exog_train": exog_train,
            "exog_test": exog_test,
        }
    else:
        return {"y": ts, "exog": df_exog}


def auto_arima_model(y_train, exog_train, diff_num):
    time_start = time.time()
    print("start auto arima...")
    # Fit model to the level to find common order
    arima_model = auto_arima(
        y=y_train,
        exogenous=exog_train,
        D=diff_num,
        seasonal=True,
        m=7,  # Weekly seasonality
    )
    time_stop = time.time()
    print(f"finished auto arima, total time: {time_stop-time_start}")
    return arima_model


def fit_arima_model(arima_model, model_name, arima_data):
    y_train = arima_data["y_train"]
    y_test = arima_data["y_test"]
    exog_train = arima_data["exog_train"]
    exog_test = arima_data["exog_test"]
    # Forecast
    arima_y_fitted = arima_model.predict_in_sample(X=exog_train)
    arima_y_forecast = arima_model.predict(n_periods=len(y_test), exogenous=exog_test)
    arima_y_forecast = pd.Series(arima_y_forecast, name="forecast", index=y_test.index)

    # metrics evaluation
    # in-sample
    mae_IS = round(mean_absolute_error(y_train, arima_y_fitted))
    mape_IS = round(mean_absolute_percentage_error(y_train, arima_y_fitted), 3)

    # out-sample
    mae_OOS = round(mean_absolute_error(y_test, arima_y_forecast), 3)
    mape_OOS = round(mean_absolute_percentage_error(y_test, arima_y_forecast), 3)
    return {
        "model": model_name,
        "mae_IS": mae_IS,
        "mae_OOS": mae_OOS,
        "mape_IS": mape_IS,
        "mape_OOS": mape_OOS,
    }


def cross_validation_result(data, model, model_name, rolls=4, horizon=30):
    """ """
    mae_CVs = []
    rmse_CVs = []
    mape_CVs = []
    mase_CVs = []
    for i in range(rolls):
        print(f"fold {i}---------------")
        y_train = data["y"].iloc[: -(rolls - i) * horizon]
        y_test = data["y"].iloc[
            np.r_[-(rolls - i) * horizon : -(rolls - i - 1) * horizon]]
        
        model.fit(
            y=y_train,
            X=data["exog"].iloc[: -(rolls - i) * horizon])
        
        y_hat = model.predict(
            n_periods=horizon,
            exogenous=data["exog"].iloc[
                np.r_[-(rolls - i) * horizon : -(rolls - i - 1) * horizon]])

        mae_CVs.append(round(mean_absolute_error(y_test, y_hat), 3))
        rmse_CVs.append(round(mean_squared_error(y_test, y_hat, square_root=True), 3))
        mape_CVs.append(round(mean_absolute_percentage_error(y_test, y_hat), 3))
        mase_CVs.append(round(mean_absolute_scaled_error(y_test, y_hat, y_train=y_train), 3))
    
    return {'store':model_name,
           'mae_ARIMA':np.mean(mae_CVs),
           'rmse_ARIMA':np.mean(rmse_CVs),
           'mape_ARIMA':np.mean(mape_CVs),
           'mase_ARIMA':np.mean(mase_CVs),
           'fc_ARIMA':y_hat,
           }

# %% [markdown]
# # tune on company data

# %%
arima_data = preprocessing(ts=df_company, df_exog=df_exog, steps_ahead=30)
print(arima_data.keys())
# Out:
# Preprocessing timeseries data with 30 steps ahead
# dict_keys(['y_train', 'y_test', 'exog_train', 'exog_test'])

# %% [markdown]
# ## grid-search
# - with auto_arima and no CV

# %%
arima_model_whole_company = auto_arima_model(
    y_train=arima_data["y_train"], 
    exog_train=arima_data["exog_train"], 
    diff_num=1
)
print(arima_model_whole_company) # ARIMA(1,0,3)(0,1,1)[7] intercept
# Out:
# start auto arima...
# finished auto arima, total time: 244.10508608818054
#  ARIMA(1,0,3)(0,1,1)[7] intercept

# %% [markdown]
# ## score with CV

# %%
arima_data_CV = preprocessing(ts=df_company, df_exog=df_exog, steps_ahead=30, split=False)
result_CV = cross_validation_result(arima_data_CV, arima_model_whole_company, 'company')
result_CV
# Out:
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# {'store': 'company',
#  'mae_ARIMA': 218.0315,
#  'rmse_ARIMA': 289.91725,
#  'mape_ARIMA': 0.29475,
#  'mase_ARIMA': 1.3667500000000001}

# %% [markdown]
# # fit on store data

# %%
# arima_model_whole_company = ARIMA((1,0,3), (0,1,1,7))

# %%
all_stores_result_CV = []
for store in df_store["store_id"].unique():#[:2]:
    time_start = time.time()
    print(f"\nprocessing stores {store}...")
    model_name = "store_" + str(store)

    # data
    df_data = df_store[df_store["store_id"] == store].set_index("date")[["sales"]]
    arima_data = preprocessing(
        ts=df_data,
        df_exog=df_exog,
        split=False,
        steps_ahead=30,)

    # fit model to each store
    cv_score = cross_validation_result(
        data=arima_data, 
        model=arima_model_whole_company, 
        model_name=model_name)

    # result
    all_stores_result_CV.append(cv_score)

    # timing
    time_stop = time.time()
    print(f"finished stores {store}, total time: {time_stop-time_start}")
    
all_stores_result_CV = pd.DataFrame(all_stores_result_CV)
# Out:
# processing stores 307222...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307222, total time: 38.93562602996826
#
# processing stores 307244...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307244, total time: 41.625200271606445
#
# processing stores 307248...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 307248, total time: 41.72073292732239
#
# processing stores 320264...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 320264, total time: 39.95443797111511
#
# processing stores 328165...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 328165, total time: 41.35044503211975
#
# processing stores 349920...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349920, total time: 40.639442920684814
#
# processing stores 349924...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349924, total time: 43.199440002441406
#
# processing stores 349952...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349952, total time: 45.484179973602295
#
# processing stores 349958...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349958, total time: 45.526166915893555
#
# processing stores 349962...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349962, total time: 45.609132051467896
#
# processing stores 349972...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349972, total time: 45.57388687133789
#
# processing stores 349978...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349978, total time: 47.529908180236816
#
# processing stores 349980...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349980, total time: 47.38224124908447
#
# processing stores 349998...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 349998, total time: 47.10886812210083
#
# processing stores 350016...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350016, total time: 50.54728293418884
#
# processing stores 350018...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350018, total time: 51.93900680541992
#
# processing stores 350026...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350026, total time: 38.172505140304565
#
# processing stores 350028...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350028, total time: 34.050832748413086
#
# processing stores 350040...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350040, total time: 32.639121770858765
#
# processing stores 350046...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350046, total time: 31.148121118545532
#
# processing stores 350054...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350054, total time: 34.95116901397705
#
# processing stores 350056...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350056, total time: 36.26318621635437
#
# processing stores 350060...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 350060, total time: 34.22693610191345
#
# processing stores 354468...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 354468, total time: 32.158710956573486
#
# processing stores 387240...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 387240, total time: 30.696731090545654
#
# processing stores 412585...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 412585, total time: 29.428454160690308
#
# processing stores 441997...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 441997, total time: 28.063685178756714
#
# processing stores 452387...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 452387, total time: 26.163426160812378
#
# processing stores 461349...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 461349, total time: 25.344027042388916
#
# processing stores 464495...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 464495, total time: 25.73125410079956
#
# processing stores 471477...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 471477, total time: 25.453205823898315
#
# processing stores 476061...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 476061, total time: 26.022337913513184
#
# processing stores 480733...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 480733, total time: 23.331974983215332
#
# processing stores 528854...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 528854, total time: 20.457236289978027
#
# processing stores 536898...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 536898, total time: 20.251724004745483
#
# processing stores 536902...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 536902, total time: 20.01008701324463
#
# processing stores 566790...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 566790, total time: 18.46267080307007
#
# processing stores 566792...
# Preprocessing timeseries data with 30 steps ahead
# fold 0---------------
# fold 1---------------
# fold 2---------------
# fold 3---------------
# finished stores 566792, total time: 19.098708868026733

# %% [markdown]
# # result

# %%
# all_stores_result_CV.to_pickle("results/f8/ARIMA.pkl")

# %%
all_stores_result_CV.head()
# Out:
#           store  mae_ARIMA  rmse_ARIMA  mape_ARIMA  mase_ARIMA  \
# 0  store_307222    9.40700    12.85200     0.32875     0.96175
# 1  store_307244    7.12975     9.58825     0.35450     0.91900
# 2  store_307248    7.06150     9.11150     0.41025     1.02925
# 3  store_320264    5.61600     7.47675     0.43950     0.82175
# 4  store_328165   29.00050    40.30175     0.45300     1.35500
#
#                                             fc_ARIMA
# 0  [37.029268763271205, 35.85993168857752, 20.326...
# 1  [16.621216340771806, 19.598568769438476, 11.74...
# 2  [21.925906231844007, 20.782152493217513, 12.86...
# 3  [11.04554411780473, 13.87814908741479, 6.02455...
# 4  [189.20752770854932, 166.71628694822704, 68.30...

# %%
all_stores_result_CV.describe()
# Out:
#        mae_ARIMA  rmse_ARIMA  mape_ARIMA  mase_ARIMA
# count  38.000000   38.000000   38.000000   38.000000
# mean    7.847007   10.608467    0.452066    1.068914
# std     5.777859    7.997232    0.085296    0.221264
# min     3.015250    3.953750    0.322000    0.795750
# 25%     4.020062    5.288375    0.383438    0.940687
# 50%     6.554000    8.794875    0.440500    1.020375
# 75%     9.063438   12.218813    0.500750    1.184063
# max    29.000500   40.301750    0.659250    1.905250
